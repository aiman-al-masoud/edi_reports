# %%
import pandas as pd

# %%
def dump_to_df(pathname):
    with open(pathname) as f:
        r = f.read()
    r=r.split("\n")
    for i in r:
        print(i)
    # print(r)

# %%
dump_to_df("./data/http1.txt")
# Out:
# https://web.unipv.it/
# ----------with cache----------
# experiment 0
# 61 requests
# Finish: 1.93 s
# experiment 1
# 43 requests
# Finish: 1.66 s
# experiment 2
# 39 requests
# Finish: 1.61 s
# experiment 3
# 40 requests
# Finish: 1.60 s
# experiment 4
# 40 requests
# Finish: 1.51 s
# ----------without cache----------
# experiment 0
# 75 requests
# Finish: 2.99 s
# experiment 1
# 75 requests
# Finish: 2.60 s
# experiment 2
# 71 requests
# Finish: 2.59 s
# experiment 3
# 71 requests
# Finish: 2.51 s
# experiment 4
# 70 requests
# Finish: 2.27 s
# https://www.pythonanywhere.com/
# ----------with cache----------
# experiment 0
# 21 requests
# Finish: 1.43 s
# experiment 1
# 7 requests
# Finish: 854 ms
# experiment 2
# 7 requests
# Finish: 835 ms
# experiment 3
# 7 requests
# Finish: 671 ms
# experiment 4
# 9 requests
# Finish: 1.61 s
# ----------without cache----------
# experiment 0
# 32 requests
# Finish: 2.66 s
# experiment 1
# 33 requests
# Finish: 2.66 s
# experiment 2
# ...
